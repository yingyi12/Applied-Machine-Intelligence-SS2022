# %% [markdown]
# *This is just a ***lecture*** notebook - you do not have to hand this in!*

# %% [markdown]
# # Lecture 01 - 03.05.2022
#
# Getting everything set up and running.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('svg')

# %%
test_data = np.random.randint(low=0, high=100, size=(1, 100))

# %%
### PLAY AROUND WITH THE HISTOGRAM AND TRY TO PLOT A MORE MEANINGFUL ONE

plt.figure(figsize=(10,5))
sns.histplot(data=test_data, bins=2, kde=True)
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
